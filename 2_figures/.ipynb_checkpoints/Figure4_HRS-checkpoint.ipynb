# %% [markdown]
# # Benchmarks

# %% [markdown]
# ## Initialize

# %%
#library(Rmisc)
library(dtplyr)
library(tidyverse)
library(glue)
library(arrow)
library(patchwork)
library(data.table)
library("jsonlite")
library(ggthemes)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     duration
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten

# %%
base_path = "/home/jakobs"

project_path = glue("{base_path}/data")
experiment = '230629'
experiment_path = glue("{project_path}/{experiment}")

endpoints_md = endpoint_defs = arrow::read_feather(glue("{base_path}/data/endpoints_epic_md.feather")) %>% filter(n_epic>=100)
endpoints = endpoint_defs$endpoint

# %%
today = experiment

# %%
base_size = 8
title_size = 10
facet_size = 10
geom_text_size=3
theme_set(theme_classic(base_size = base_size) + 
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0), 
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major=element_line()))
# Out:
# Warning message:
# “The `size` argument of `element_line()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”

# %%
endpoint_map = endpoint_defs$phecode_string
names(endpoint_map) =  endpoint_defs$endpoint
endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint

# %%
endpoint_selection = c(
    # generally very important
    "phecode_202", # Diabetes mellitus
    "phecode_401",	#Hypertension"  
    "phecode_404", # Ischemic heart disease   
    "phecode_404-1", # Myocardial infarction [Heart attack]
    "phecode_431-11", # Cerebral infarction [Ischemic stroke]
    "phecode_424", # Heart failure

    
    "phecode_059-1", # COVID 19
    "phecode_468", # Pneumonia
    "phecode_474", # Chronic obstructive pulmonary disease [COPD]
      
    "phecode_286-2", #	Major depressive disorder
    "phecode_324-11", #Parkinson's Disease
    "phecode_328", # Dementias and cerebral degeneration

    
    "phecode_164", # Anemia
    "phecode_726-1", # Osteoporosis
    "phecode_371", # Cataract
    "phecode_374-42", # Diabetic retinopathy
    "phecode_374-5", # Macular degeneration
    "phecode_375-1", # Glaucoma
    
    
    "phecode_103", # Malignant neoplasm of the skin
    "phecode_101", # Malignant neoplasm of the digestive organs
    "phecode_102", # LUNG CANCER
    
    "phecode_583", # Chronic kidney disease    
    "phecode_542", # Chronic liver disease and sequelae    
    "OMOP_4306655" # All-Cause Death
    
    # also generally important and relevant
    #"phecode_440-3", # Pulmonary embolism
    #"phecode_468-1",	#Viral pneumonia
#     "phecode_460-2",	#Acute lower respiratory infection
    #"phecode_388" # Blindness and low vision
      # generally important and fun to check
   # "phecode_374-3", # Retinal vascular changes and occlusions
    #"phecode_665", # Psoriasis
#     "phecode_121", # Leukemia
    # important for eye
#     "phecode_705-1", # Rheumatoid arthritis
)

endpoints_common = c(
   'phecode_164', #Anemia
 'phecode_705-1', #Rheumatoid arthritis
 'phecode_328', #Dementias and cerebral degeneration
 'phecode_328-1', #Alzheimer's disease
 'phecode_401', #Hypertension
 'phecode_202', #Diabetes mellitus
 'phecode_416-21', #Atrial fibrillation
 'phecode_404-1', #Myocardial infarction [Heart attack]
 'phecode_424', #Heart failure
 'phecode_468', #Pneumonia
 'phecode_474', #Chronic obstructive pulmonary disease [COPD]
 'phecode_583', #Chronic kidney disease
 'OMOP_4306655' #All-Cause Death
    )
    
endpoints_cardio = c(
    'phecode_438-11',   #  "Abdominal aortic aneurysm",
    'phecode_440-3',#  "Pulmonary embolism", # intervention
    'phecode_413-21',#  "Aortic stenosis", # intervention
    'phecode_400'#  "Rheumatic fever and chronic rheumatic heart diseases",	
)

endpoints_eye= c(
    'phecode_374-5', #Macular degeneration
 'phecode_374-51', #Age-related macular degeneration
 'phecode_374-42', #Diabetic retinopathy
 'phecode_371', #Cataract
 'phecode_388', #Blindness and low vision
 'phecode_367-5', #Uveitis
 'phecode_389-1' #Ocular pain
)

# %%
endpoint_defs = endpoint_defs %>% 
    mutate(name = phecode_string) %>%
    mutate(name = 
           case_when( 
               phecode_string == "Myocardial infarction [Heart attack]"~"Myocardial infarction",
               phecode_string == "Cerebral infarction [Ischemic stroke]"~"Ischemic stroke",
               phecode_string == "Chronic obstructive pulmonary disease [COPD]"~"Chronic obstructive pulmonary disease",
               phecode_string == "Mitral valve insufficiency"~"Mitral insufficiency",
               phecode_string == "Parkinson's disease (Primary)"~"Parkinson's disease",
               phecode_string == "Suicide ideation and attempt or self harm"~"Suicide attempt",
               phecode_string == "Ischemic heart disease"~"Coronary heart disease",
               phecode_string == "Chronic kidney disease"~"Chronic kidney disease",
               phecode_string == "Rheumatic fever and chronic rheumatic heart diseases"~"Rheumatic heart disease",
               phecode_string == "Abdominal aortic aneurysm"~"Abdominal aortic aneurysm",
                  TRUE ~ name)
           )
            
endpoint_map = endpoint_defs$name
names(endpoint_map) =  endpoint_defs$endpoint
#endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint
endpoint_order = endpoint_selection

# %%
endpoints_cardio = c(
    'phecode_431-11', #  "Cerebral infarction [Ischemic stroke]",
    'phecode_404', #  "Ischemic heart disease",
    'phecode_404-1', #  "Myocardial infarction [Heart attack]", # intervention
    'phecode_424', #  "Heart failure", # intervention
     'OMOP_4306655', #  "All-Cause Death", # intervention
    'phecode_420' #  "Cardiac arrest", # intervention
   
)

# %% [markdown]
# ## Load data

# %% [markdown]
# # Load Benchmarks

# %%
name = "hrs_endpoints"
hrs_endpoints = arrow::read_feather(glue("{experiment_path}/{name}.feather"), 
                                    col_select=c("endpoint", "score", "partition", "hrs_ret", "hrs_ret_age", "hrs_ret_sex")) %>% 
    left_join(endpoint_defs) %>% filter(n_epic>=100)
# Out:
# Joining with `by = join_by(endpoint)`

# %%
hrs_endpoints
# Out:
#      endpoint     score          partition hrs_ret   hrs_ret_age hrs_ret_sex
# 1    OMOP_4306655 ASCVD+Retina   0         1.588715  NA          NA
# 2    OMOP_4306655 ASCVD+Retina   1         1.517196  NA          NA
# 3    OMOP_4306655 ASCVD+Retina   2         1.557983  NA          NA
# 4    OMOP_4306655 ASCVD+Retina   3         1.542834  NA          NA
# 5    OMOP_4306655 ASCVD+Retina   4         1.560359  NA          NA
# 6    OMOP_4306655 ASCVD+Retina   5         1.490507  NA          NA
# 7    OMOP_4306655 ASCVD+Retina   6         1.518358  NA          NA
# 8    OMOP_4306655 ASCVD+Retina   7         1.560944  NA          NA
# 9    OMOP_4306655 ASCVD+Retina   8         1.514556  NA          NA
# 10   OMOP_4306655 ASCVD+Retina   9         1.515054  NA          NA
# 11   OMOP_4306655 Age+Sex+Retina 0         1.903806  NA          NA
# 12   OMOP_4306655 Age+Sex+Retina 1         1.657563  NA          NA
# 13   OMOP_4306655 Age+Sex+Retina 2         1.883887  NA          NA
# 14   OMOP_4306655 Age+Sex+Retina 3         1.785274  NA          NA
# 15   OMOP_4306655 Age+Sex+Retina 4         1.762481  NA          NA
# 16   OMOP_4306655 Age+Sex+Retina 5         1.593559  NA          NA
# 17   OMOP_4306655 Age+Sex+Retina 6         1.704891  NA          NA
# 18   OMOP_4306655 Age+Sex+Retina 7         1.929616  NA          NA
# 19   OMOP_4306655 Age+Sex+Retina 8         1.616813  NA          NA
# 20   OMOP_4306655 Age+Sex+Retina 9         1.794386  NA          NA
# 21   OMOP_4306655 Retina         0         4.382692  NA          NA
# 22   OMOP_4306655 Retina         1         3.774130  NA          NA
# 23   OMOP_4306655 Retina         2         4.167873  NA          NA
# 24   OMOP_4306655 Retina         3         4.005980  NA          NA
# 25   OMOP_4306655 Retina         4         4.228734  NA          NA
# 26   OMOP_4306655 Retina         5         3.774999  NA          NA
# 27   OMOP_4306655 Retina         6         3.878935  NA          NA
# 28   OMOP_4306655 Retina         7         3.995482  NA          NA
# 29   OMOP_4306655 Retina         8         3.923558  NA          NA
# 30   OMOP_4306655 Retina         9         3.739278  NA          NA
# ⋮    ⋮            ⋮              ⋮         ⋮         ⋮           ⋮
# 6851 phecode_829  Age+Sex+Retina 0         0.9997837 NA          NA
# 6852 phecode_829  Age+Sex+Retina 1         0.8893900 NA          NA
# 6853 phecode_829  Age+Sex+Retina 2         0.8107518 NA          NA
# 6854 phecode_829  Age+Sex+Retina 3         0.9545334 NA          NA
# 6855 phecode_829  Age+Sex+Retina 4         0.8383505 NA          NA
# 6856 phecode_829  Age+Sex+Retina 5         1.0454274 NA          NA
# 6857 phecode_829  Age+Sex+Retina 6         0.9328581 NA          NA
# 6858 phecode_829  Age+Sex+Retina 7         1.0247820 NA          NA
# 6859 phecode_829  Age+Sex+Retina 8         0.8674446 NA          NA
# 6860 phecode_829  Age+Sex+Retina 9         0.9106519 NA          NA
# 6861 phecode_829  Retina         0         3.1707274 NA          NA
# 6862 phecode_829  Retina         1         3.0976157 NA          NA
# 6863 phecode_829  Retina         2         2.9683775 NA          NA
# 6864 phecode_829  Retina         3         3.7069555 NA          NA
# 6865 phecode_829  Retina         4         3.4085722 NA          NA
# 6866 phecode_829  Retina         5         2.9530368 NA          NA
# 6860 Nonspecific findings on examination of blood
# 6861 Nonspecific findings on examination of blood
# 6862 Nonspecific findings on examination of blood
# 6863 Nonspecific findings on examination of blood
# 6864 Nonspecific findings on examination of blood
# 6865 Nonspecific findings on examination of blood
# 6866 Nonspecific findings on examination of blood
# 6867 Nonspecific findings on examination of blood
# 6868 Nonspecific findings on examination of blood
# 6869 Nonspecific findings on examination of blood
# 6870 Nonspecific findings on examination of blood
# 6871 Nonspecific findings on examination of blood
# 6872 Nonspecific findings on examination of blood
# 6873 Nonspecific findings on examination of blood
# 6874 Nonspecific findings on examination of blood
# 6875 Nonspecific findings on examination of blood
# 6876 Nonspecific findings on examination of blood
# 6877 Nonspecific findings on examination of blood
# 6878 Nonspecific findings on examination of blood
# 6879 Nonspecific findings on examination of blood
# 6880 Nonspecific findings on examination of blood

# %% [raw]
# hrs_endpoints %>% filter(score %in% c("Age+Sex+Retina", "Retina")) %>% group_by(endpoint) %>% tally()# %>% arrange(n)

# %%
hrs = hrs_endpoints %>% 
    group_by(endpoint, score, phecode_string, phecode_category) %>% 
    #filter(score %in% c("Retina", "Age+Sex+Retina", "Age+Sex+Retina+I(Age*ret)")) %>%
    #mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    #mutate(phecode_category = factor(phecode_category, levels=pcats_sorted)) %>%
    select(endpoint, score, hrs_ret, hrs_ret_age, hrs_ret_sex, phecode_string, phecode_category) %>%
    ungroup()
hrs
# Out:
#      endpoint     score          hrs_ret   hrs_ret_age hrs_ret_sex
# 1    OMOP_4306655 ASCVD+Retina   1.588715  NA          NA
# 2    OMOP_4306655 ASCVD+Retina   1.517196  NA          NA
# 3    OMOP_4306655 ASCVD+Retina   1.557983  NA          NA
# 4    OMOP_4306655 ASCVD+Retina   1.542834  NA          NA
# 5    OMOP_4306655 ASCVD+Retina   1.560359  NA          NA
# 6    OMOP_4306655 ASCVD+Retina   1.490507  NA          NA
# 7    OMOP_4306655 ASCVD+Retina   1.518358  NA          NA
# 8    OMOP_4306655 ASCVD+Retina   1.560944  NA          NA
# 9    OMOP_4306655 ASCVD+Retina   1.514556  NA          NA
# 10   OMOP_4306655 ASCVD+Retina   1.515054  NA          NA
# 11   OMOP_4306655 Age+Sex+Retina 1.903806  NA          NA
# 12   OMOP_4306655 Age+Sex+Retina 1.657563  NA          NA
# 13   OMOP_4306655 Age+Sex+Retina 1.883887  NA          NA
# 14   OMOP_4306655 Age+Sex+Retina 1.785274  NA          NA
# 15   OMOP_4306655 Age+Sex+Retina 1.762481  NA          NA
# 16   OMOP_4306655 Age+Sex+Retina 1.593559  NA          NA
# 17   OMOP_4306655 Age+Sex+Retina 1.704891  NA          NA
# 18   OMOP_4306655 Age+Sex+Retina 1.929616  NA          NA
# 19   OMOP_4306655 Age+Sex+Retina 1.616813  NA          NA
# 20   OMOP_4306655 Age+Sex+Retina 1.794386  NA          NA
# 21   OMOP_4306655 Retina         4.382692  NA          NA
# 22   OMOP_4306655 Retina         3.774130  NA          NA
# 23   OMOP_4306655 Retina         4.167873  NA          NA
# 24   OMOP_4306655 Retina         4.005980  NA          NA
# 25   OMOP_4306655 Retina         4.228734  NA          NA
# 26   OMOP_4306655 Retina         3.774999  NA          NA
# 27   OMOP_4306655 Retina         3.878935  NA          NA
# 28   OMOP_4306655 Retina         3.995482  NA          NA
# 29   OMOP_4306655 Retina         3.923558  NA          NA
# 30   OMOP_4306655 Retina         3.739278  NA          NA
# ⋮    ⋮            ⋮              ⋮         ⋮           ⋮
# 6851 phecode_829  Age+Sex+Retina 0.9997837 NA          NA
# 6852 phecode_829  Age+Sex+Retina 0.8893900 NA          NA
# 6853 phecode_829  Age+Sex+Retina 0.8107518 NA          NA
# 6854 phecode_829  Age+Sex+Retina 0.9545334 NA          NA
# 6855 phecode_829  Age+Sex+Retina 0.8383505 NA          NA
# 6856 phecode_829  Age+Sex+Retina 1.0454274 NA          NA
# 6857 phecode_829  Age+Sex+Retina 0.9328581 NA          NA
# 6858 phecode_829  Age+Sex+Retina 1.0247820 NA          NA
# 6859 phecode_829  Age+Sex+Retina 0.8674446 NA          NA
# 6860 phecode_829  Age+Sex+Retina 0.9106519 NA          NA
# 6861 phecode_829  Retina         3.1707274 NA          NA
# 6862 phecode_829  Retina         3.0976157 NA          NA
# 6863 phecode_829  Retina         2.9683775 NA          NA
# 6864 phecode_829  Retina         3.7069555 NA          NA
# 6865 phecode_829  Retina         3.4085722 NA          NA
# 6866 phecode_829  Retina         2.9530368 NA          NA
# 6867 phecode_829  Retina         3.5115242 NA          NA
# 6868 phecode_829  Retina         3.3379900 NA          NA
# 6869 phecode_829  Retina         3.2832212 NA          NA
# 6870 phecode_829  Retina         3.5339376 NA          NA
# 6871 phecode_829  SCORE2+Retina  1.3336002 NA          NA
# 6872 phecode_829  SCORE2+Retina  1.2659344 NA          NA
# 6873 phecode_829  SCORE2+Retina  1.2279272 NA          NA
# 6874 phecode_829  SCORE2+Retina  1.3340580 NA          NA
# 6875 phecode_829  SCORE2+Retina  1.2657609 NA          NA
# 6876 phecode_829  SCORE2+Retina  1.3005755 NA          NA
# 6877 phecode_829  SCORE2+Retina  1.3193694 NA          NA
# 6878 phecode_829  SCORE2+Retina  1.3426292 NA          NA
# 6879 phecode_829  SCORE2+Retina  1.2836910 NA          NA
# 6880 phecode_829  SCORE2+Retina  1.3186517 NA          NA
#      phecode_string                               phecode_category
# 1    All-Cause Death                              Death
# 2    All-Cause Death                              Death
# 3    All-Cause Death                              Death
# 4    All-Cause Death                              Death
# 5    All-Cause Death                              Death
# 6    All-Cause Death                              Death
# 7    All-Cause Death                              Death
# 8    All-Cause Death                              Death
# 9    All-Cause Death                              Death
# 10   All-Cause Death                              Death
# 11   All-Cause Death                              Death
# 12   All-Cause Death                              Death
# 13   All-Cause Death                              Death
# 14   All-Cause Death                              Death
# 15   All-Cause Death                              Death
# 16   All-Cause Death                              Death
# 17   All-Cause Death                              Death
# 18   All-Cause Death                              Death
# 19   All-Cause Death                              Death
# 20   All-Cause Death                              Death
# 21   All-Cause Death                              Death
# 22   All-Cause Death                              Death
# 23   All-Cause Death                              Death
# 24   All-Cause Death                              Death
# 25   All-Cause Death                              Death
# 26   All-Cause Death                              Death
# 27   All-Cause Death                              Death
# 28   All-Cause Death                              Death
# 29   All-Cause Death                              Death
# 30   All-Cause Death                              Death
# ⋮    ⋮                                            ⋮
# 6851 Nonspecific findings on examination of blood Signs/Symptoms
# 6852 Nonspecific findings on examination of blood Signs/Symptoms
# 6853 Nonspecific findings on examination of blood Signs/Symptoms
# 6854 Nonspecific findings on examination of blood Signs/Symptoms
# 6855 Nonspecific findings on examination of blood Signs/Symptoms
# 6856 Nonspecific findings on examination of blood Signs/Symptoms
# 6857 Nonspecific findings on examination of blood Signs/Symptoms
# 6858 Nonspecific findings on examination of blood Signs/Symptoms
# 6859 Nonspecific findings on examination of blood Signs/Symptoms
# 6860 Nonspecific findings on examination of blood Signs/Symptoms
# 6861 Nonspecific findings on examination of blood Signs/Symptoms
# 6862 Nonspecific findings on examination of blood Signs/Symptoms
# 6863 Nonspecific findings on examination of blood Signs/Symptoms
# 6864 Nonspecific findings on examination of blood Signs/Symptoms
# 6865 Nonspecific findings on examination of blood Signs/Symptoms
# 6866 Nonspecific findings on examination of blood Signs/Symptoms
# 6867 Nonspecific findings on examination of blood Signs/Symptoms
# 6868 Nonspecific findings on examination of blood Signs/Symptoms
# 6869 Nonspecific findings on examination of blood Signs/Symptoms
# 6870 Nonspecific findings on examination of blood Signs/Symptoms
# 6871 Nonspecific findings on examination of blood Signs/Symptoms
# 6872 Nonspecific findings on examination of blood Signs/Symptoms
# 6873 Nonspecific findings on examination of blood Signs/Symptoms
# 6874 Nonspecific findings on examination of blood Signs/Symptoms
# 6875 Nonspecific findings on examination of blood Signs/Symptoms
# 6876 Nonspecific findings on examination of blood Signs/Symptoms
# 6877 Nonspecific findings on examination of blood Signs/Symptoms
# 6878 Nonspecific findings on examination of blood Signs/Symptoms
# 6879 Nonspecific findings on examination of blood Signs/Symptoms
# 6880 Nonspecific findings on examination of blood Signs/Symptoms

# %%
unique(hrs$score)
# Out:
# [1] "ASCVD+Retina"   "Age+Sex+Retina" "Retina"         "SCORE2+Retina"

# %%
purrr::map_dfr(integer(100), ~ hrs %>% group_by(endpoint, score) %>% sample_frac(1, replace=TRUE), .id="i") -> temp_hrs

# %%
library(ggdist)

# %%
temp_hrs_ret = temp_hrs %>% group_by(endpoint, score, phecode_string, phecode_category) %>% median_qi(hrs_ret, hrs_ret_age, hrs_ret_sex, na.rm=TRUE)

# %%
temp_hrs_linear = temp_hrs %>% ungroup() %>%
    filter(score %in% c("Retina",
                        "Age+Sex+Retina"
#                        "SCORE2+Retina",
#                        "ASCVD+Retina",
#                        "QRISK3+Retina"
                       )) %>%
    group_by(endpoint, score, phecode_string, phecode_category) %>% 
    median_qi(`hrs_ret`, na.rm=TRUE) %>% rename(hr = `hrs_ret`) %>%
    mutate(hr = round(hr, 2), .lower=round(.lower, 2), .upper=round(.upper, 2)) %>%#c(hr, .lower, .upper), round, 1) %>%
    mutate(HR_Retina = as.character(glue("{hr} ({.lower}, {.upper})"))) %>% 
    select(endpoint, score, phecode_string, phecode_category, HR_Retina) %>%
    pivot_wider(names_from="score", values_from="HR_Retina") %>% 
    select(all_of(c("phecode_category", "endpoint", "phecode_string", "Retina", 'Age+Sex+Retina'
#                     "SCORE2+Retina", "ASCVD+Retina","QRISK3+Retina"
                   ))) %>% 
    #mutate(endpoint = factor(endpoint, levels = endpoint_order)) %>% 
    arrange(endpoint) %>%
    #mutate(endpoint = recode(endpoint, !!!endpoint_map)) %>%
    ungroup()
    
temp_hrs_linear

# %%
ukb = fread("SupplTables - ST6_ HazardRatiosAll.csv")

# %%
ukb

# %%
epic = temp_hrs_linear %>% select(-phecode_category, -phecode_string)
colnames(epic) = c("endpoint", "epic_unadjusted", "epic_agesex")
epic

# %%
st6 = ukb %>% left_join(epic, by="endpoint") %>% as_tibble() %>% arrange(endpoint)

# %%
st6_clean <- st6 %>%
  mutate(across(everything(), ~ replace_na(., ""), .names = "{col}"))

# %%
st6_clean %>% write_csv("outputs/SupplTable6_ukbepic_merged.csv")

# %%
# new, after bugfix
temp_hrs_linear %>% filter(endpoint %in% endpoint_selection) %>% select(-phecode_category)
# Out:
#    endpoint       phecode_string
# 1  OMOP_4306655   All-Cause Death
# 2  phecode_101    Malignant neoplasm of the digestive organs
# 3  phecode_103    Malignant neoplasm of the skin
# 4  phecode_164    Anemia
# 5  phecode_202    Diabetes mellitus
# 6  phecode_286-2  Major depressive disorder
# 7  phecode_328    Dementias and cerebral degeneration
# 8  phecode_371    Cataract
# 9  phecode_401    Hypertension
# 10 phecode_404    Ischemic heart disease
# 11 phecode_404-1  Myocardial infarction [Heart attack]
# 12 phecode_424    Heart failure
# 13 phecode_431-11 Cerebral infarction [Ischemic stroke]
# 14 phecode_468    Pneumonia
# 15 phecode_474    Chronic obstructive pulmonary disease [COPD]
# 16 phecode_583    Chronic kidney disease
# 17 phecode_726-1  Osteoporosis
#    Retina            Age+Sex+Retina
# 1  3.92 (3.74, 4.38) 1.79 (1.59, 1.93)
# 2  2.27 (2.02, 2.49) 1.17 (1.02, 1.22)
# 3  3.57 (3.24, 3.76) 1.11 (0.99, 1.32)
# 4  2.69 (2.52, 2.84) 1.42 (1.27, 1.54)
# 5  3.71 (3.16, 3.9)  3.04 (2.52, 3.18)
# 6  3.17 (2.69, 4.7)  2.44 (1.7, 3.01)
# 7  3.58 (3.4, 3.86)  1.12 (1.05, 1.25)
# 8  3.68 (3.56, 3.81) 2.95 (2.84, 3.06)
# 9  3.86 (3.79, 4.08) 2.06 (2, 2.18)
# 10 2.9 (2.72, 3.06)  1.22 (1.17, 1.32)
# 11 3.91 (3.59, 4.28) 1.6 (1.4, 1.69)
# 12 3.45 (3.39, 3.67) 1.32 (1.2, 1.44)
# 13 3.54 (3.39, 3.87) 1.67 (1.44, 1.79)
# 14 3.98 (3.74, 4.31) 1.54 (1.47, 1.65)
# 15 3.85 (3.61, 4.01) 2.67 (2.42, 2.77)
# 16 4.52 (4.27, 4.77) 1.63 (1.51, 1.69)
# 17 3.15 (3, 3.36)    1.55 (1.42, 1.61)

# %%
temp_hrs_linear %>% 
    filter(phecode_string %in% tmp_sign$phecode_string) %>%
    select(-phecode_category) %>%
    write_csv("outputs/SupplTable2_HRsLinearSIGNIFICANT_CropRatio-0.66.csv")
